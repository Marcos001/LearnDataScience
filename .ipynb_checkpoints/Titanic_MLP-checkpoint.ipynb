# %% [markdown]
# # [Titanic: Machine Learning from Disaster](https://www.kaggle.com/c/titanic)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 
from sklearn.metrics import confusion_matrix
from mlxtend.plotting import plot_learning_curves
from sklearn.model_selection import train_test_split


# 
from keras.models import Sequential
from keras.utils import np_utils
from keras.layers.core import Dense, Activation, Dropout

sns.set()
# %matplotlib inline

# %% [markdown]
# # Pré-Processamento
# ## Carrega o conjunto de treinamento e teste

# %%
train = pd.read_csv('dataset/Titanic/train.csv')
test = pd.read_csv('dataset/Titanic/test.csv')
train.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# ## Visualizando meus dados
#
# ### Histograma

# %%
train.hist(figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5349253080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f53472138d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f53471c2390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5347169e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f53471958d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5347195908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f53470e7e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f53471158d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f53470c4390>]], dtype=object)

# %% [markdown]
# ### Correlação Entre cada Couna

# %%
corr = train.corr()
plt.figure(figsize=(12, 7))
sns.heatmap(corr, annot=True)

# %% [markdown]
# ### Boxplot de cada coluna

# %%
train.plot(kind='box', figsize=(12, 8), subplots=True, layout=(3, 3))
# Out:
# PassengerId       AxesSubplot(0.125,0.657941;0.227941x0.222059)
# Survived       AxesSubplot(0.398529,0.657941;0.227941x0.222059)
# Pclass         AxesSubplot(0.672059,0.657941;0.227941x0.222059)
# Age               AxesSubplot(0.125,0.391471;0.227941x0.222059)
# SibSp          AxesSubplot(0.398529,0.391471;0.227941x0.222059)
# Parch          AxesSubplot(0.672059,0.391471;0.227941x0.222059)
# Fare                 AxesSubplot(0.125,0.125;0.227941x0.222059)
# dtype: object

# %% [markdown]
# ## Deleta as informações irrelevantes

# %%
train = train.drop(['Name', 'Ticket', 'Cabin'], axis=1)
test = test.drop(['Name', 'Ticket', 'Cabin'], axis=1)

# %% [markdown]
# # Visualizando valores nulos
# Transforma as colunas de palavras em numeros

# %%
new_data_train = pd.get_dummies(train)
new_data_test = pd.get_dummies(test)

# %% [markdown]
# Aplica uma correção para os valores nulos - setar  média entre eles

# %%
new_data_train['Age'].fillna(new_data_train['Age'].mean(), inplace=True)
new_data_test['Fare'].fillna(new_data_test['Fare'].mean(), inplace=True)

# %% [markdown]
# Define o conjunto de features e labels

# %%
x = new_data_train.drop('Survived', axis=1)
y = new_data_train['Survived'].values.astype('int32')

x = (x.values).astype('float32')
y = np_utils.to_categorical(y) 

print(x.shape)
print(y.shape)
# Out:
# (891, 11)
# (891, 2)

# %%
#x = normalize(x)

# %% [markdown]
# Separa os dados em um conjunto de treinamento e teste

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
# pre-processing: divide by max and substract mean

def pre_process(tensor):
    scale = np.max(tensor)
    mean = np.std(x_train)
    
    tensor /= scale
    tensor -= mean
    
    return tensor
    
x_train = pre_process(x_train)
x_test = pre_process(x_test)


camada_de_entrada = x_train.shape[1]
classes = y_train.shape[1]

print('classes : ',classes,' Camada de Entrada da MLP : ', camada_de_entrada)
# Out:
# classes :  2  Camada de Entrada da MLP :  11

# %% [markdown]
# ## Definindo o modelo
# ### Simple ANN with Keras

# %%
def ANN(entrada, nb_classes):
    # Here's a Deep Dumb MLP (DDMLP)
    model = Sequential()
    model.add(Dense(128, input_dim=entrada))
    model.add(Activation('relu'))
    model.add(Dropout(0.15))
    model.add(Dense(128))
    model.add(Activation('relu'))
    model.add(Dropout(0.15))
    model.add(Dense(nb_classes))
    model.add(Activation('softmax'))
    return model

ann = ANN(camada_de_entrada, classes)

# %% [markdown]
# ### Compile the model

# %%
ann.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ### Treinando o modelo

# %%
log = ann.fit(x_train, y_train, epochs=5, batch_size=1, validation_split=0.1,  verbose=1)
# Out:
# Train on 640 samples, validate on 72 samples
# Epoch 1/5
# 640/640 [==============================] - 3s 5ms/step - loss: 0.6725 - acc: 0.6062 - val_loss: 0.6456 - val_acc: 0.6667
# Epoch 2/5
# 640/640 [==============================] - 3s 5ms/step - loss: 0.6724 - acc: 0.6062 - val_loss: 0.6474 - val_acc: 0.6667
# Epoch 3/5
# 640/640 [==============================] - 3s 5ms/step - loss: 0.6718 - acc: 0.6062 - val_loss: 0.6469 - val_acc: 0.6667
# Epoch 4/5
# 640/640 [==============================] - 3s 5ms/step - loss: 0.6715 - acc: 0.6062 - val_loss: 0.6452 - val_acc: 0.6667
# Epoch 5/5
# 640/640 [==============================] - 3s 5ms/step - loss: 0.6714 - acc: 0.6062 - val_loss: 0.6453 - val_acc: 0.6667

# %%
acuracia = ann.evaluate(x_test, y_test)
print(acuracia)
#print('Acuracia  sobre os dados de Teste : ',acuracia[len(acuracia)-1])

log.history.keys() # 'val_loss', 'val_acc', 'loss', 'acc'
print(log.history['val_loss'][len(log.history['val_loss'])-1])
print(log.history['val_acc'][len(log.history['val_acc'])-1])
print(log.history['loss'][len(log.history['loss'])-1])
print(log.history['acc'][len(log.history['acc'])-1])
# Out:
# 179/179 [==============================] - 0s 123us/step
# [0.6600059067736791, 0.63128491586813051]
# 0.645280679067
# 0.666666666667
# 0.671353927022
# 0.60625

# %%
titulo = " Model Loss - Treinamento "

plt.plot(log.history['val_loss'], '--go', label='val_loss')
plt.plot(log.history['val_acc'], '--ro', label='val_acc')

plt.plot(log.history['loss'], '--mo', label='loss')
plt.plot(log.history['acc'], '--bo', label='acc')

plt.title(titulo)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(loc='upper center', shadow=True, fontsize='x-large',  bbox_to_anchor=(1.25, 0.7), ncol=1)

# %% [markdown]
# ### Gerando predições do teste

# %%
preds = ann.predict_classes(x_test, verbose=1)
# Out:
# 179/179 [==============================] - 0s 85us/step

# %% [markdown]
# ## Referências
#  * [Simple Deep MLP with Keras](https://www.kaggle.com/fchollet/simple-deep-mlp-with-keras)
#  * [ANN to classifier Voice](https://www.kaggle.com/siddu1998/artificial-neural-network-to-classify-voice)
#  * [Prima Indians Diabetes](https://www.kaggle.com/surya635/pima-indians-diabetes)
